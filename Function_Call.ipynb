# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisurekar05-ship-it/Python-Ass/blob/main/Function_Call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check prime number

def check_prime(num):

    if num <= 1:
        return "Not Prime"

    for i in range(2, num):

        if num % i == 0:
            return "Not Prime"

    return "Prime"

result = check_prime(7)

print(result)
# Out:
# Prime

# %%
# Function to find largest number from list

def largest_number(numbers):

    return max(numbers)

nums = [10, 45, 67, 23, 89]

result = largest_number(nums)

print(result)
# Out:
# 89

# %%
# Function to count vowels in string

def count_vowels(text):

    vowels = "aeiouAEIOU"

    count = 0

    for char in text:

        if char in vowels:
            count = count + 1

    return count

result = count_vowels("Hello Python")

print(result)
# Out:
# 3
