# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisurekar05-ship-it/Python-Ass/blob/main/Lambda_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lambda function to add two numbers

add = lambda a, b: a + b

print(add(5, 3))
# Out:
# 8

# %%
# Lambda function to find square of a number

square = lambda x: x * x

print(square(4))
# Out:
# 16

# %%
# Lambda function to check even or odd

check = lambda x: "Even" if x % 2 == 0 else "Odd"

print(check(7))
# Out:
# Odd

# %%
# Lambda function to find maximum of two numbers

maximum = lambda a, b: a if a > b else b

print(maximum(10, 20))
# Out:
# 20

# %%
# Lambda function to sort list in ascending order

numbers = [5, 2, 9, 1, 7]

sorted_list = sorted(numbers)

print(sorted_list)
# Out:
# [1, 2, 5, 7, 9]
