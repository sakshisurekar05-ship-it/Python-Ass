# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisurekar05-ship-it/Python-Ass/blob/main/For_Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print numbers from 1 to 50 using for loop

for i in range(1, 51):
    print(i)

# %%
# Print all even numbers between 1 and 100

for i in range(1, 101):
    if i % 2 == 0:
        print(i)

# %%
# Find the sum of first N natural numbers

n = int(input("Enter N: "))

total = 0

for i in range(1, n + 1):
    total = total + i

print("Sum =", total)

# %%
# Display multiplication table using for loop

num = int(input("Enter number: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)

# %%
# Count how many numbers are divisible by 5

numbers = [10, 12, 15, 18, 20, 25, 33, 40]

count = 0

for i in numbers:
    if i % 5 == 0:
        count = count + 1

print("Numbers divisible by 5 =", count)
